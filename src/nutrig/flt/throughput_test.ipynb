# %%
import numpy as np

import matplotlib.pyplot as plt

plt.style.use('tableau-colorblind10')
plt.style.use('/pbs/home/p/pcorrea/tools/matplotlib_style_sans-serif.txt')

# %matplotlib inline

# %%
n_iter = 2e4
n_temp = [3,5,10,96]
t_comp = [6.986,11.439,22.762,222.383] # [s]

plt.plot(n_temp,n_iter/t_comp,marker='o',markersize=10)
plt.xscale('log')
plt.xlabel('Number of templates')
plt.ylabel('Throughput rate [Hz]')
plt.show()
